# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.13.1'

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %%
print(x_train[0])

# %%
import matplotlib.pyplot as plt
x_train=tf.keras.utils.normalize(x_train,axis=1)
x_test=tf.keras.utils.normalize(x_test,axis=1)
plt.imshow(x_train[0])
plt.show()

# %%
model=tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(x_train, y_train, epochs=3)
# Out:
# WARNING:tensorflow:From C:\Users\sahin\AppData\Local\Continuum\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Epoch 1/3
# 60000/60000 [==============================] - 31s 525us/sample - loss: 0.2663 - acc: 0.9209
# Epoch 2/3
# 60000/60000 [==============================] - 42s 706us/sample - loss: 0.1072 - acc: 0.9669 - loss: 0.1077
# Epoch 3/3
# 60000/60000 [==============================] - 27s 447us/sample - loss: 0.0733 - acc: 0.9768

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss)
print(val_acc)
# Out:
# 10000/10000 [==============================] - 2s 240us/sample - loss: 0.0983 - acc: 0.9706
# 0.09828171304576098
# 0.9706

# %%
model.save('epic_num_reader.model')

# %%
new_model = tf.keras.models.load_model('epic_num_reader.model')
# Out:
# WARNING:tensorflow:Sequential models without an `input_shape` passed to the first layer cannot reload their optimizer state. As a result, your model isstarting with a freshly initialized optimizer.

# %%
predictions = new_model.predict(x_test)

# %%
print(predictions)
# Out:
# [[7.5082185e-10 2.1573130e-09 1.7448102e-06 ... 9.9996626e-01
#   3.5593548e-08 3.4893077e-07]
#  [5.7665517e-07 2.8244709e-04 9.9969172e-01 ... 1.4945332e-08
#   9.9015017e-07 5.3993480e-11]
#  [7.6803538e-08 9.9984181e-01 1.2099180e-06 ... 1.1094112e-04
#   2.5132600e-05 2.5924521e-06]
#  ...
#  [9.0657669e-11 2.2955269e-06 1.4139146e-08 ... 7.1549446e-05
#   4.5505232e-07 4.6521320e-05]
#  [3.7519437e-06 1.0768090e-06 5.6459076e-08 ... 2.5364257e-05
#   3.7682775e-04 1.2633413e-07]
#  [3.0023944e-07 2.6932210e-09 4.6436315e-07 ... 4.3732487e-12
#   4.4599549e-08 3.8832639e-09]]

# %%
import numpy as np

print(np.argmax(predictions[0]))
# Out:
# 7

# %%
plt.imshow(x_test[0],cmap=plt.cm.binary)
plt.show()

# %%
import numpy as np
np.binary_repr(5)
# Out:
# '101'

# %%
# Open the session
import tensorflow as tf
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

for i in range(steps):
# Get the next batch
   input_batch, labels_batch = next_batch(100)
    feed_dict = {x_input: input_batch, y_labels: labels_batch}

   # Print the current batch accuracy every 100 steps
   if i%100 == 0:
        train_accuracy = accuracy.eval(feed_dict=feed_dict)
        print("Step %d, training batch accuracy %g"%(i, train_accuracy))

   # Run the optimization step
   train_step.run(feed_dict=feed_dict)

# Print the test accuracy once the training is over
print("Test accuracy: %g"%accuracy.eval(feed_dict={x_input: test_images, y_labels: test_labels}))

# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt
import os 
path=r"cats and dogs\train"
ic=['cat','dog']
for i in ic:
    y=os.path.join(path,i)
    for new_path in os.listdir(y):
        im_arr=cv2.imread(os.path.join(y,new_path), cv2.IMREAD_GRAYSCALE)
        plt.imshow(im_arr,cmap='gray')
        plt.show()
        break
    break

# %%
im_arr.shape
# Out:
# (374, 500)

# %%
ims=200
new=cv2.resize(im_arr,(ims,ims))
plt.imshow(new, cmap='gray')
plt.show()

# %%
help(cv2.resize)

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt 
IM_SIZ=100
train_data=[]

DATADIR=r"C:\Users\sahin\PetImages"
CATEGORIES=['Cat', 'Dog']
for category in CATEGORIES:
    liste=os.path.join(path,category)
    liste1=os.listdir(liste)
    for i in liste1:
        ak=cv2.imread(os.path.join(liste,i), cv2.IMREAD_GRAYSCALE)
        new_shape=cv2.resize(ak, (IM_SIZ,IM_SIZ))
        plt.imshow(new_shape,cmap='gray')
        plt.show()
        break
    break

# %%
clas_num=CATEGORIES.index(category)
print(clas_num)
# Out:
# 0

# %%
help(cv2.resize)

# %%
from tqdm import tqdm
training_data=[]

DATADIR=r"C:\Users\sahin\PetImages"
CATEGORIES=['Cat', 'Dog']
IMG_SIZE=200

def create_training_data():
    for category in CATEGORIES:  # do dogs and cats
        path = os.path.join(DATADIR,category)  # create path to dogs and cats
        class_num = CATEGORIES.index(category)  # get the classification  (0 or a 1). 0=dog 1=cat
        
        for img in tqdm(os.listdir(path)):  # iterate over each image per dogs and cats
            try:
                img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
                training_data.append([new_array,class_num])  # add this to our training_data
            except Exception as e:  # in the interest in keeping the output clean...
                pass
        
                
            


create_training_data()
print(len(training_data))
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 12501/12501 [06:59<00:00, 29.78it/s]
# 24946

# %%
DATADIR=r"C:\Users\sahin\PetImages"
IM_SIZ=100
data_set=[]

CATEGORIES=['Cat','Dog']
def train_set():
    for category in CATEGORIES:
        clas_num=CATEGORIES.index(category)
        path=os.path.join(DATADIR, category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_shape1=cv2.resize(img_array, (IM_SIZ,IM_SIZ))
                data_set.append([new_shape1,clas_num])
            except Exception as e:
                pass

    
                    

train_set()
len((data_set))
# Out:
# 24946

# %%
X=[]
Y=[]
IM_S=100
for features, labels  in data_set:
    features=np.array(features).reshape((IM_S,IM_S,1))
    X.append(features)
    Y.append(labels)


print(Y[:])

# %%
rest=np.shape(X)
rest
# Out:
# (24946, 100, 100, 1)

# %%
rest1=np.shape(Y)
rest1
# Out:
# (24946,)

# %%
import pickle 
import numpy as np
with open('X.pickle','wb') as pickle_out:
    pickle.dump(X,pickle_out)
with open("Y.pickle","wb") as pickl_out:
    pickle.dump(Y,pickl_out )

# %%
with open("X.pickle","rb") as pickle_in:
    first=pickle.Unpickler(pickle_in)
    X=first.load()

# %%
with open("Y.pickle","rb") as pickle_in1:
    first=pickle.Unpickler(pickle_in1)
    Y=first.load()

# %%
result=np.shape(Y)[:]
(result)
# Out:
# (24946,)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

import pickle

with open("X.pickle","rb") as pickle_in:
    first=pickle.Unpickler(pickle_in)
    X=first.load()
    X=np.divide(X,255)
with open("Y.pickle","rb") as pickle_in1:
    first1=pickle.Unpickler(pickle_in1)
    Y=first1.load()
    X=np.divide(X,255)
    

    
model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=(100,100,1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

model.add(Dense(64))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(X, Y, batch_size=30, epochs=5, validation_split=0.1)
tf.__version__
